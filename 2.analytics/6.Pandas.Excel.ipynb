# %% [markdown]
# # Работа с Excel
# - создание из датафрейма

# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame({
    "A":{1:100, 2:200, 3:300},
    "B":{1:1000, 2:2000, 3:3000}
})
df
# Out:
#      A     B
# 1  100  1000
# 2  200  2000
# 3  300  3000

# %%
df.to_excel("test.xlsx")

# %%
data = pd.read_csv("titanic.csv")
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
count_data = data.groupby(["survived", "pclass", "who"])[["who"]].count()
count_data
# Out:
#                        who
# survived pclass who
# 0        1      child    1
#                 man     77
#                 woman    2
#          2      man     91
#                 woman    6
#          3      child   33
#                 man    281
#                 woman   58
# 1        1      child    5
#                 man     42
#                 woman   89
#          2      child   19
#                 man      8
#                 woman   60
#          3      child   25
#                 man     38
#                 woman   56

# %%
mean_data = data.groupby()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-77450f2c40b1> in <module>
# ----> 1 mean_data = data.groupby()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6712
#    6713         if level is None and by is None:
# -> 6714             raise TypeError("You have to supply one of 'by' and 'level'")
#    6715         axis = self._get_axis_number(axis)
#    6716
#
# TypeError: You have to supply one of 'by' and 'level'

# %%
df.to_excel("titanic.xlsx")

# %%
# создание эксель-файла с заданным названием листа
df.to_excel("titanic.xlsx", sheet_name="Titanic")

# %%
# создание движка для записи нескольких датафреймов
#определение движка для записи нескольких датафреймов
excelWriter = pd.ExcelWriter("bigTitanic.xlsx", engine="xlsxwriter")

#создание эксель
data.to_excel()
